# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import ibgeparser
# import da classe principal
from ibgeparser.microdados import Microdados
# import dos enums para facilitar as buscas
from ibgeparser.enums import Anos, Estados, Modalidades

# %%
documentacao = pd.read_csv('microdados-ibge/Documentacao_Pessoas.csv')
documentacao
# Out:
#      Unnamed: 0    VAR                                               NOME  \
# 0             0  V0001  UNIDADE DA FEDERAÇÃO:\n11- Rondônia\n12- Acre\...
# 1             1  V0002                                CÓDIGO DO MUNICÍPIO
# 2             2  V0011                                 ÁREA DE PONDERAÇÃO
# 3             3  V0300                                           CONTROLE
# 4             4  V0010                                      PESO AMOSTRAL
# ..          ...    ...                                                ...
# 239         239  M0604        MARCA DE IMPUTAÇÃO NA V0604\n1- Sim\n2- Não
# 240         240  M0605        MARCA DE IMPUTAÇÃO NA V0605\n1- Sim\n2- Não
# 241         241  M6462        MARCA DE IMPUTAÇÃO NA V6462\n1- Sim\n2- Não
# 242         242  M6472        MARCA DE IMPUTAÇÃO NA V6472\n1- Sim\n2- Não
# 243         243  V1005  Situação do setor \n1 - Área urbanizada\n2 - Á...
#
#      POSIÇÃO INICIAL  POSIÇÃO FINAL  INT   DEC TIPO
# 0                  1              2    2   NaN    A
# 1                  3              7    5   NaN    A
# 2                  8             20   13   NaN    A
# 3                 21             28    8   NaN    N
# 4                 29             44    3  13.0    N
# ..               ...            ...  ...   ...  ...
# 239              536            536    1   NaN    C
# 240              537            537    1   NaN    C
# 241              538            538    1   NaN    C
# 242              539            539    1   NaN    C
# 243              540            540    1   NaN    C
#
# [244 rows x 8 columns]
